# %%
ls
# Out:
# model5.csv  sample_data/

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('model5.csv')

# %%
data.head()
# Out:
#   Brand Name  Factory CS  Coller size  Chest  Shoulder  Length      Type  \
# 0     Robato        14.0         14.0  35.10     15.75    28.5  slim fit
# 1     Robato        14.0         14.0  35.25     15.75    28.5  slim fit
# 2     Robato        14.0         14.0  35.50     15.75    28.5  slim fit
# 3     Robato        14.0         14.0  35.75     15.75    28.5  slim fit
# 4     Robato        14.0         14.0  36.00     15.75    28.5  slim fit
#
#   Stuck_At                   Fit Score
# 0   thight  Thight in your chest area.
# 1   thight  Thight in your chest area.
# 2   thight  Thight in your chest area.
# 3   thight  Thight in your chest area.
# 4   thight  Thight in your chest area.

# %%
data.shape
# Out:
# (11760, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11760 entries, 0 to 11759
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Brand Name   11760 non-null  object
#  1   Factory CS   11760 non-null  float64
#  2   Coller size  11760 non-null  float64
#  3   Chest        11760 non-null  float64
#  4   Shoulder     11760 non-null  float64
#  5   Length       11760 non-null  float64
#  6   Type         11760 non-null  object
#  7   Stuck_At     11760 non-null  object
#  8   Fit Score    11760 non-null  object
# dtypes: float64(5), object(4)
# memory usage: 827.0+ KB

# %%
data.isnull().sum()
# Out:
# Brand Name     0
# Factory CS     0
# Coller size    0
# Chest          0
# Shoulder       0
# Length         0
# Type           0
# Stuck_At       0
# Fit Score      0
# dtype: int64

# %%
data = data.drop(columns=['Stuck_At','Coller size'])

# %%
data.head(2)
# Out:
#   Brand Name  Factory CS  Chest  Shoulder  Length      Type  \
# 0     Robato        14.0  35.10     15.75    28.5  slim fit
# 1     Robato        14.0  35.25     15.75    28.5  slim fit
#
#                     Fit Score
# 0  Thight in your chest area.
# 1  Thight in your chest area.

# %%
data = pd.get_dummies(data, columns=['Brand Name','Type'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11760 entries, 0 to 11759
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Factory CS         11760 non-null  float64
#  1   Chest              11760 non-null  float64
#  2   Shoulder           11760 non-null  float64
#  3   Length             11760 non-null  float64
#  4   Fit Score          11760 non-null  object
#  5   Brand Name_Robato  11760 non-null  bool
#  6   Type_slim fit      11760 non-null  bool
#  7   Type_trim fit      11760 non-null  bool
# dtypes: bool(3), float64(4), object(1)
# memory usage: 494.0+ KB

# %%
data.shape
# Out:
# (11760, 8)

# %%
data.head(2)
# Out:
#    Factory CS  Chest  Shoulder  Length                   Fit Score  \
# 0        14.0  35.10     15.75    28.5  Thight in your chest area.
# 1        14.0  35.25     15.75    28.5  Thight in your chest area.
#
#    Brand Name_Robato  Type_slim fit  Type_trim fit
# 0               True           True          False
# 1               True           True          False

# %%
x = data.drop('Fit Score',axis=1)
y = data['Fit Score']

# %%
import sklearn
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

Rfc = RandomForestClassifier()
Rfc.fit(x_train, y_train)
score = Rfc.score(x_test, y_test)
print(score)
# Out:
# 0.9874149659863946

# %%
correct_sum = []
for i in range(1,20):
  model = RandomForestClassifier()
  model.fit(x_train,y_train)
  pred = model.predict(x_test)
  correct = np.sum(pred == y_test)
  correct_sum.append(correct)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,pred)
cm
# Out:
# array([[737,   0,   0,   0,   6,   0,   0,   0,   0],
#        [  0, 274,   0,   0,   0,   0,   0,   0,   0],
#        [  0,   0, 256,   2,   0,   0,   0,   0,   2],
#        [  0,   0,   0, 275,   0,   0,   0,   0,   0],
#        [  3,   0,   0,   0, 277,   0,   1,   0,   0],
#        [  0,   0,   0,   0,   0, 269,   0,   9,   0],
#        [  0,   0,   0,   0,   1,   0, 272,   0,   0],
#        [  0,   0,   0,   0,   0,   2,   1, 264,   0],
#        [  3,   0,   1,   0,   0,   1,   0,   0, 284]])

# %%
import pickle
with open('rfcpredictor3.pickle','wb') as file:
  pickle.dump(Rfc,file)

# %%
x_train.columns
# Out:
# Index(['Factory CS', 'Chest', 'Shoulder', 'Length', 'Brand Name_Robato',
#        'Type_slim fit', 'Type_trim fit'],
#       dtype='object')

# %%
Rfc.predict([[17,50,18,30.5,1,1,0]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['Thight in your chest area and loose in your shoulder area.'],
#       dtype=object)
